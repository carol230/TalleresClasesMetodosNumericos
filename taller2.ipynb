# %% [markdown]
# # Taller 2 09-nov

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f(x):
    return x**3 - 3*x**2 + x - 1

# Create an array of x values
x = np.linspace(-2, 4, 400)
y = f(x)

# Plot the function
plt.plot(x, y, label='f(x) = x^3 - 3x^2 + x - 1')
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')
plt.title('Plot of the function f(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid()
plt.show()

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = x**3 - 3 * x**2 + x - 1
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %%
from scipy.optimize import newton

# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.newton.html
x0 = 100
points = []
x_r = newton(f, x0, args=(points,True),maxiter=100)  # Este no es método de Newton, es secante!
# Out:
# f(100.0) = 970099.0
# f(100.01010000000001) = 970395.9803980006
# f(67.00792386980214) = 287465.54571529943
# f(53.116335372259854) = 141447.59273483977
# f(39.65955343460801) = 57699.74450824955
# f(30.388236067683557) = 25320.914914632634
# f(23.137873990336278) = 10803.174516522931
# f(17.742617932460977) = 4657.725983130829
# f(13.65347387896111) = 1998.6458316465025
# f(10.579948354366646) = 858.043795817009
# f(8.267818948297682) = 367.35922412035336
# f(6.536804537670478) = 156.66380304361124
# f(5.249698727272358) = 66.24990348675587
# f(4.306584492248163) = 27.539375882553202
# f(3.6356358117218313) = 11.037373198988304
# f(3.1868714328556598) = 4.084765647739281
# f(2.923215343365569) = 1.2670760212328207
# f(2.804652849575538) = 0.26803700410227016
# f(2.772843145360331) = 0.02631152581509344
# f(2.7693806975473843) = 0.0006530032799583196
# f(2.769292579076204) = 1.6618166540638413e-06
# f(2.7692923542528955) = 1.0542855477524427e-10

# %%
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="$x^3 - 3x^2 + x - 1$")
plt.axhline(0, color="black", linewidth=0.5)
plt.axvline(0, color="black", linewidth=0.5)
plt.scatter(x_r, f(x_r), color="red", zorder=5)  # Add the root to the plot
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of the equation $x^3 - 3x^2 + x - 1$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.show()

# %%
# Extract x values from points
x_points = [point[0] for point in points]

# Plot the x points
plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %%
from scipy.optimize import newton

# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.newton.html
x0 = -0.75
points = []
x_r = newton(f, x0, args=(points,True), maxiter = 50, disp = False)  # Este no es método de Newton, es secante!
# Out:
# f(-0.75) = -3.859375
# f(-0.750175) = -3.8606329732866094
# f(-0.2131121088266221) = -1.3590412854408869
# f(0.07865838494705255) = -0.9394163690607865
# f(0.7318464277935389) = -1.4829747970630462
# f(-1.0502276885887563) = -6.51754052554591
# f(1.2567717428295437) = -2.4966140809744046
# f(2.6891996533313134) = -0.558444669923817
# f(3.101925046224713) = 3.082641622796059
# f(2.752500623776417) = -0.12261892209412961
# f(2.7658680381983984) = -0.02524755812170909
# f(2.7693340939132134) = 0.00030851495857353584
# f(2.7692922514113585) = -7.600154772191559e-07
# f(2.7692923542355494) = -2.2780000108468812e-11

# %%
from scipy.optimize import newton

# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.newton.html
x0 = -1
points = []
x_r = newton(
    f, x0, args=(points, True), maxiter=100
)  # Este no es método de Newton, es secante!
# Out:
# f(-1.0) = -6.0
# f(-1.0002) = -6.002000240008
# f(-0.40007199376044494) = -1.944279357559926
# f(-0.11251734714285737) = -1.1519222942429534
# f(0.3055272738835656) = -0.9459934428847171
# f(2.225935549440168) = -2.6093905298716624
# f(-0.7866314478975496) = -4.129757466766417
# f(7.396374081543759) = 246.90595135720395
# f(-0.6520138337576513) = -3.2045654027231674
# f(-0.5488930782005125) = -2.6181164009056803
# f(-0.08852544084207464) = -1.1127294539448893
# f(0.2517622378613702) = -0.9224326811942098
# f(1.9012514609656634) = -3.0704576412075024
# f(-0.4565827744142934) = -2.1771690842380034
# f(-6.203218352555335) = -361.3423052459625
# f(-0.42174810907673893) = -2.030379466687118
# f(-0.3890785046817195) = -1.9021242675113228
# f(0.09543711518477387) = -0.9310183492475942
# f(0.5599517722463857) = -1.205115558242392
# f(-1.4823668719657201) = -12.33197157683866
# f(0.7811490240949828) = -1.5727800797435725
# f(1.1120300863447232) = -2.2226541121759515
# ...

# %% [markdown]
# # Ejercicio En Clase

# %%
from scipy.optimize import newton
import matplotlib.pyplot as plt
import numpy as np

roots = []
values = []

def f(x: float, show: bool = False):
    y = x**3 - 3 * x**2 + x - 1
    roots.append(x)       
    values.append(y)      
    if show:
        print(f"f({x}) = {y}")
    return y

def f_prime(x: float):
    return 3 * x**2 - 6 * x + 1

x0 = 100

x_r = newton(lambda x: f(x, True), x0, fprime=f_prime, maxiter=100)

print("Raíz encontrada:", x_r)
print("Estimaciones de raíces:", roots)
# Out:
# f(100.0) = 970099.0
# f(67.00455766810653) = 287421.5546044976
# f(45.009926065596666) = 85151.64374336696
# f(30.35039723527028) = 25223.076156622286
# f(20.582860416480248) = 7468.634520318185
# f(14.079716839009599) = 2209.5053464848224
# f(9.757835905944379) = 652.2076251031732
# f(6.898518561069087) = 191.4272950525605
# f(5.028701696557697) = 55.330187134373084
# f(3.843680657951718) = 15.30811830079546
# f(3.1559707952275144) = 3.709463570275677
# f(2.8454158843448356) = 0.593842355835478
# f(2.773143092634202) = 0.0285402881796184
# f(2.7693029596247096) = 7.838698133211253e-05
# f(2.7692923543194023) = 5.96992677515118e-10
# Raíz encontrada: 2.7692923542386314
# Estimaciones de raíces: [100.0, 67.00455766810653, 45.009926065596666, 30.35039723527028, 20.582860416480248, 14.079716839009599, 9.757835905944379, 6.898518561069087, 5.028701696557697, 3.843680657951718, 3.1559707952275144, 2.8454158843448356, 2.773143092634202, 2.7693029596247096, 2.7692923543194023]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(roots, values, marker='o', color="orange", linestyle='-', label="Estimaciones del método de Newton")

plt.axhline(0, color="black", linewidth=0.5)  
plt.ylabel("f(x)")
plt.title("Trayectoria de las estimaciones (Método de Newton)")
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.show()
