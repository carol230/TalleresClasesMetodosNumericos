# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f(x):
    return x**3 - 3*x**2 + x - 1

# Create an array of x values
x = np.linspace(-2, 4, 400)
y = f(x)

# Plot the function
plt.plot(x, y, label='f(x) = x^3 - 3x^2 + x - 1')
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')
plt.title('Plot of the function f(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid()
plt.show()

# %%
# from scipy.optimize import newton

# x0 = 100

# x_r = newton(f, x0)

# x_r
# Out:
# 2.7692923542386314

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# # Define the function
# def f(x):
#     return x**3 - 3*x**2 + x - 1

# # Generate x values
# x = np.linspace(-5, 5, 400)
# y = f(x)

# # Create the plot
# plt.figure(figsize=(8, 6))
# plt.plot(x, y, label='f(x) = x^2 - 4', color='blue')
# plt.axhline(0, color='black', lw=0.5, ls='--')
# plt.axvline(0, color='black', lw=0.5, ls='--')
# plt.scatter(x_r, f(x_r), color='red', zorder=5, label='Roots')
# plt.title('Plot of the function and its roots')
# plt.xlabel('x')
# plt.ylabel('f(x)')
# plt.legend()
# plt.grid()
# plt.ylim(-10, 10)
# plt.show()

# %%
# def f(x):
#     y = x*3 - 3*x*2 + x - 1 
#     print(f'f({x}) = {y}')  # Corrected to use x
#     return y

# x0 = 100  # Initial guess

# # Find the root using Newton's method
# x_r = newton(f, x0)

# x_r  # This will display the root found
# Out:
# f(100.0) = -201.0
# f(100.01010000000001) = -201.0202
# f(-0.5000000001474959) = 2.9499203080263214e-10
# -0.4999999999999999

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = x*3 - 3*x*2 + x - 1 
    points.append((x,y))
    if show:
        print(f'f({x}) = {y}')  # Corrected to use x
    return y

# %%
from scipy.optimize import newton

x0 = 100  # Initial guess
points= []
x_r = newton(f,x0,args=(points, False)) 
x_r
# Out:
# -0.4999999999999999

# %%
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="$x^3 - 3x^2 + x - 1$")
plt.axhline(0, color="black", linewidth=0.5)
plt.axvline(0, color="black", linewidth=0.5)
plt.scatter(x_r, f(x_r), color="red", zorder=5)  # Add the root to the plot
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of the equation $x^3 - 3x^2 + x - 1$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.show()

# %%
# Extract x values from points
x_points = [point[0] for point in points]

# Plot the x points
plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()
